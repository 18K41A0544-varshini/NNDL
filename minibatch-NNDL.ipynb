# %%
import pandas as pd
data={'x':[0.2,0.4,0.6,0.8],
      'y':[3.4,3.8,4.2,4.6]}
df=pd.DataFrame(data)

print(df)
# Out:
#      x    y
# 0  0.2  3.4
# 1  0.4  3.8
# 2  0.6  4.2
# 3  0.8  4.6

# %%
it=1
max_it=100
n=0.1
m=1
c=-1
s=0
ns=4
bs=2
deltam=1
deltac=1
derm=1
sum1=0
sum2=0
n1=0
nb=(ns/bs)
print("nb",nb)
bt=1
while it<=max_it:
    i=0
    j=0
    bt=1
    while bt<=nb:
        sum1=0;
        sum2=0;
        #print(j)
        for i in range(bs):
            print(j)
            m1=m
            c1=c
            one=(df.iloc[j]['y'])
            print(one)
            
            two=(df.iloc[j]['x'])
            print(two)
            #print("sum1",sum1)
            #print("sum2",sum2)
            #print("m is",m)
            #print("c is",c)
            sum1=sum1+((one-(m1*two)-c1)*two)
            sum2=sum2+(one-(m1*two)-c1)
                #sum1=sum1+((one-(m1*two)-c1)*two)
                #sum2=sum2+(one-(m1*two)-c1)
                
            print("sum1",sum1)
            print("sum2",sum2)
            i=i+1
            
            print("j is",j)
            j=j+1
        derm=-(1/bs)*sum1
        deltam=-(n)*derm
        m=m+deltam
        derc=-(1/bs)*sum2
        deltac=-(n)*derc
        c=c+deltac
        print("value of m is",m)
        print("value of c is",c)
        print("batch",bt) 
        bt=bt+1
    print("iteration",it)
    it=it+1
   
    

print("m value is",m)
print("c value is",c)
# Out:
# nb 2.0
# 0
# 3.4
# 0.2
# sum1 0.8399999999999999
# sum2 4.199999999999999
# j is 0
# 1
# 3.8
# 0.4
# sum1 2.6
# sum2 8.6
# j is 1
# value of m is 1.13
# value of c is -0.5700000000000001
# batch 1
# 2
# 4.2
# 0.6
# sum1 2.4552
# sum2 4.0920000000000005
# j is 2
# 3
# 4.6
# 0.8
# sum1 5.868
# sum2 8.358
# j is 3
# value of m is 1.4234
# value of c is -0.1521
# batch 2
# iteration 1
# 0
# 3.4
# 0.2
# sum1 0.6534840000000001
# sum2 3.26742
# j is 0
# 1
# 3.8
# 0.4
# sum1 2.00658
# sum2 6.65016
# j is 1
# value of m is 1.523729
# value of c is 0.180408
# batch 1
# 2
# 4.2
# 0.6
# sum1 1.8632127600000001
# sum2 3.1053546000000005
# j is 2
# 3
# 4.6
# 0.8
# sum1 4.4236998
# sum2 6.3059633999999996
# j is 3
# value of m is 1.74491399
# value of c is 0.49570617
# batch 2
# iteration 2
# 0
# 3.4
# 0.2
# sum1 0.5110622064
# sum2 2.5553110319999996
# j is 0
# 1
# 3.8
# 0.4
# sum1 1.5535934999999998
# sum2 5.161639266
# j is 1
# value of m is 1.8225936649999999
# value of c is 0.7537881333
# ...
