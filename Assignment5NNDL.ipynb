# %%
import pandas as pd
data={'x':[0.2,0.4,0.6,0.8],
      'y':[3.4,3.8,4.2,4.6]}
df=pd.DataFrame(data)

print(df['x'])
# Out:
# 0    0.2
# 1    0.4
# 2    0.6
# 3    0.8
# Name: x, dtype: float64

# %%
it=0
max_it=100
n=0.1
m=1
c=-1
s=0
ns=4
deltam=1
deltac=1
derm=1
sum1=0
sum2=0
n1=0

while it<max_it:
    i=0
    while n1<ns:
        for i in range(len(df)):
            m1=m
            c1=c
            one=(df.iloc[i]['y'])
            two=(df.iloc[i]['x'])
            sum1=sum1+((one-(m1*two)-c1)*two)
            sum2=sum2+(one-(m1*two)-c1)
            print(sum1)
            print(sum2)
            n1=n1+1
        i=i+1
            
    derm=-(1/ns)*sum1
    deltam=-(n)*derm
    m=m+deltam
    derc=-(1/ns)*sum2
    deltac=-(n)*derc
    c=c+deltac
    
    print("value of m is",m)
    print("value of c is",c)
    it=it+1
    print("iteration",it)
    

print("m value is",m)
print("c value is",c)
# Out:
# 0.8399999999999999
# 4.199999999999999
# 2.6
# 8.6
# 5.359999999999999
# 13.2
# 9.2
# 18.0
# value of m is 1.23
# value of c is -0.55
# iteration 1
# value of m is 1.46
# value of c is -0.10000000000000003
# iteration 2
# value of m is 1.69
# value of c is 0.35
# iteration 3
# value of m is 1.92
# value of c is 0.8
# iteration 4
# value of m is 2.15
# value of c is 1.25
# iteration 5
# value of m is 2.38
# value of c is 1.7
# iteration 6
# value of m is 2.61
# value of c is 2.15
# iteration 7
# value of m is 2.84
# value of c is 2.6
# iteration 8
# value of m is 3.07
# value of c is 3.0500000000000003
# iteration 9
# value of m is 3.3
# value of c is 3.5000000000000004
# iteration 10
# value of m is 3.53
# value of c is 3.9500000000000006
# iteration 11
# value of m is 3.76
# value of c is 4.4
# iteration 12
# value of m is 3.9899999999999998
# value of c is 4.8500000000000005
# iteration 13
# value of m is 4.22
# value of c is 5.300000000000001
# iteration 14
# value of m is 4.449999999999999
# value of c is 5.750000000000001
# iteration 15
# value of m is 4.68
# value of c is 6.200000000000001
# iteration 16
# value of m is 4.91
# value of c is 6.650000000000001
# iteration 17
# value of m is 5.140000000000001
# value of c is 7.100000000000001
# iteration 18
# value of m is 5.370000000000001
# value of c is 7.550000000000002
# iteration 19
# value of m is 5.600000000000001
# value of c is 8.000000000000002
# iteration 20
# value of m is 5.830000000000002
# value of c is 8.450000000000001
# iteration 21
# value of m is 6.060000000000002
# value of c is 8.9
# iteration 22
# value of m is 6.290000000000003
# value of c is 9.35
# iteration 23
# value of m is 6.520000000000003
# value of c is 9.799999999999999
# iteration 24
# value of m is 6.7500000000000036
# value of c is 10.249999999999998
# iteration 25
# value of m is 6.980000000000004
# value of c is 10.699999999999998
# iteration 26
# value of m is 7.210000000000004
# value of c is 11.149999999999997
# iteration 27
# value of m is 7.440000000000005
# value of c is 11.599999999999996
# iteration 28
# value of m is 7.670000000000005
# value of c is 12.049999999999995
# iteration 29
# value of m is 7.900000000000006
# value of c is 12.499999999999995
# iteration 30
# value of m is 8.130000000000006
# value of c is 12.949999999999994
# iteration 31
# value of m is 8.360000000000007
# value of c is 13.399999999999993
# iteration 32
# value of m is 8.590000000000007
# value of c is 13.849999999999993
# iteration 33
# value of m is 8.820000000000007
# value of c is 14.299999999999992
# iteration 34
# value of m is 9.050000000000008
# value of c is 14.749999999999991
# iteration 35
# value of m is 9.280000000000008
# value of c is 15.19999999999999
# iteration 36
# value of m is 9.510000000000009
# value of c is 15.64999999999999
# iteration 37
# value of m is 9.740000000000009
# value of c is 16.09999999999999
# iteration 38
# value of m is 9.97000000000001
# value of c is 16.54999999999999
# iteration 39
# value of m is 10.20000000000001
# value of c is 16.99999999999999
# iteration 40
# value of m is 10.43000000000001
# value of c is 17.44999999999999
# iteration 41
# value of m is 10.66000000000001
# value of c is 17.899999999999988
# iteration 42
# value of m is 10.890000000000011
# value of c is 18.349999999999987
# iteration 43
# value of m is 11.120000000000012
# value of c is 18.799999999999986
# iteration 44
# value of m is 11.350000000000012
# value of c is 19.249999999999986
# iteration 45
# value of m is 11.580000000000013
# value of c is 19.699999999999985
# iteration 46
# value of m is 11.810000000000013
# value of c is 20.149999999999984
# iteration 47
# value of m is 12.040000000000013
# value of c is 20.599999999999984
# iteration 48
# value of m is 12.270000000000014
# value of c is 21.049999999999983
# iteration 49
# value of m is 12.500000000000014
# value of c is 21.499999999999982
# iteration 50
# value of m is 12.730000000000015
# value of c is 21.94999999999998
# iteration 51
# value of m is 12.960000000000015
# value of c is 22.39999999999998
# iteration 52
# value of m is 13.190000000000015
# value of c is 22.84999999999998
# iteration 53
# value of m is 13.420000000000016
# value of c is 23.29999999999998
# iteration 54
# value of m is 13.650000000000016
# value of c is 23.74999999999998
# iteration 55
# value of m is 13.880000000000017
# value of c is 24.199999999999978
# iteration 56
# value of m is 14.110000000000017
# value of c is 24.649999999999977
# iteration 57
# value of m is 14.340000000000018
# value of c is 25.099999999999977
# iteration 58
# value of m is 14.570000000000018
# value of c is 25.549999999999976
# iteration 59
# value of m is 14.800000000000018
# value of c is 25.999999999999975
# iteration 60
# value of m is 15.030000000000019
# value of c is 26.449999999999974
# iteration 61
# value of m is 15.26000000000002
# value of c is 26.899999999999974
# iteration 62
# value of m is 15.49000000000002
# value of c is 27.349999999999973
# iteration 63
# value of m is 15.72000000000002
# value of c is 27.799999999999972
# iteration 64
# value of m is 15.95000000000002
# value of c is 28.24999999999997
# iteration 65
# value of m is 16.18000000000002
# value of c is 28.69999999999997
# iteration 66
# value of m is 16.41000000000002
# value of c is 29.14999999999997
# iteration 67
# value of m is 16.640000000000022
# value of c is 29.59999999999997
# iteration 68
# value of m is 16.870000000000022
# value of c is 30.04999999999997
# iteration 69
# value of m is 17.100000000000023
# value of c is 30.499999999999968
# iteration 70
# value of m is 17.330000000000023
# value of c is 30.949999999999967
# iteration 71
# value of m is 17.560000000000024
# value of c is 31.399999999999967
# iteration 72
# value of m is 17.790000000000024
# value of c is 31.849999999999966
# iteration 73
# value of m is 18.020000000000024
# value of c is 32.29999999999997
# iteration 74
# value of m is 18.250000000000025
# value of c is 32.74999999999997
# iteration 75
# value of m is 18.480000000000025
# value of c is 33.199999999999974
# iteration 76
# value of m is 18.710000000000026
# value of c is 33.64999999999998
# iteration 77
# value of m is 18.940000000000026
# value of c is 34.09999999999998
# iteration 78
# value of m is 19.170000000000027
# value of c is 34.54999999999998
# iteration 79
# value of m is 19.400000000000027
# value of c is 34.999999999999986
# iteration 80
# value of m is 19.630000000000027
# value of c is 35.44999999999999
# iteration 81
# value of m is 19.860000000000028
# value of c is 35.89999999999999
# iteration 82
# value of m is 20.09000000000003
# value of c is 36.349999999999994
# iteration 83
# value of m is 20.32000000000003
# value of c is 36.8
# iteration 84
# value of m is 20.55000000000003
# value of c is 37.25
# iteration 85
# value of m is 20.78000000000003
# value of c is 37.7
# iteration 86
# value of m is 21.01000000000003
# value of c is 38.150000000000006
# iteration 87
# value of m is 21.24000000000003
# value of c is 38.60000000000001
# iteration 88
# value of m is 21.47000000000003
# value of c is 39.05000000000001
# iteration 89
# value of m is 21.70000000000003
# value of c is 39.500000000000014
# iteration 90
# value of m is 21.93000000000003
# value of c is 39.95000000000002
# iteration 91
# value of m is 22.160000000000032
# value of c is 40.40000000000002
# iteration 92
# value of m is 22.390000000000033
# value of c is 40.85000000000002
# iteration 93
# value of m is 22.620000000000033
# value of c is 41.300000000000026
# iteration 94
# value of m is 22.850000000000033
# value of c is 41.75000000000003
# iteration 95
# value of m is 23.080000000000034
# value of c is 42.20000000000003
# iteration 96
# value of m is 23.310000000000034
# value of c is 42.650000000000034
# iteration 97
# value of m is 23.540000000000035
# value of c is 43.10000000000004
# iteration 98
# value of m is 23.770000000000035
# value of c is 43.55000000000004
# iteration 99
# value of m is 24.000000000000036
# value of c is 44.00000000000004
# iteration 100
# m value is 24.000000000000036
# c value is 44.00000000000004
